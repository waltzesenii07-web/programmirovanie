# %%
import pygame 
pygame.init() 

screen = pygame.display.set_mode((794, 1123)) 
pygame.display.set_caption("Кот")

running = True 
while running: 
    for event in pygame.event.get(): 
        if event.type == pygame.QUIT: 
            running = False

    screen.fill((85,68,0))
    mouse_x, mouse_y = pygame.mouse.get_pos()


#пол
    pygame.draw.rect(screen, (128,102,0), (0,510,794,713)) 

#окно
    pygame.draw.rect(screen, (135,205,222), (427,36,363,467))   
    pygame.draw.rect(screen, (213,255,230), (427,36,363,27))   
    pygame.draw.rect(screen, (213,255,230), (427,36,27,467)) 
    pygame.draw.rect(screen, (213,255,230), (763,36,27,467)) 
    pygame.draw.rect(screen, (213,255,230), (427,476,363,27)) 
    pygame.draw.rect(screen, (213,255,230), (593,36,27,467)) 
    pygame.draw.rect(screen, (213,255,230), (427,185,363,27)) 

#кот 
    pygame.draw.polygon(screen, (200,113,55), [ (603, 630), (673, 652), (768, 665), (793,667), (793, 738), (708,732), (610,677), (603,630)])
    pygame.draw.polygon(screen, (68,40,15), [ (603, 630), (673, 652), (768, 665), (793,667), (793, 738), (708,732), (610,677), (603,630)], 2)
    pygame.draw.ellipse(screen, (200,113,55), (577,652 , 220, 80))
    pygame.draw.ellipse(screen, (68,40,15), (577,652 , 220, 80), 2)
    pygame.draw.polygon(screen, (200,113,55), [ (603, 632), (668, 654), (659, 671), (607,667), (603, 632)])
    pygame.draw.polygon(screen, (200,113,55), [ (709, 730), (793, 728), (793, 673), (770,667), (709, 730)])
    pygame.draw.ellipse(screen, (200,113,55), (117,530,502,291))
    pygame.draw.ellipse(screen, (68,40,15), (117,530,502,291), 2)
    pygame.draw.ellipse(screen, (200,113,55), (448,644,180,180))
    pygame.draw.ellipse(screen, (68,40,15), (448,644,180,180),2)
    pygame.draw.ellipse(screen, (200,113,55), (588,754,69,146))
    pygame.draw.ellipse(screen, (68,40,15), (588,754,69,146), 2)
    pygame.draw.ellipse(screen, (200,113,55), (122,732,138,80))
    pygame.draw.ellipse(screen, (68,40,15), (122,732,138,80),2)
    pygame.draw.ellipse(screen, (200,113,55), (60,609,74,160))
    pygame.draw.ellipse(screen, (68,40,15), (60,609,74,160),2)
    pygame.draw.ellipse(screen, (200,113,55), (14,546,230,199))
    pygame.draw.ellipse(screen, (68,40,15), (14,546,230,199),2)
    pygame.draw.ellipse(screen, (136,170,0), (53,622,66,70))
    pygame.draw.ellipse(screen, (1,1,0), (53,622,66,70),1)
    pygame.draw.ellipse(screen, (1,1,0), (91,626,10,60))
    pygame.draw.ellipse(screen, (255,255,255), (61,639,30,20))
    pygame.draw.ellipse(screen, (136,170,0), (146,622,66,70))
    pygame.draw.ellipse(screen, (1,1,0), (146,622,66,70),1)
    pygame.draw.ellipse(screen, (1,1,0), (184,626,10,60))
    pygame.draw.ellipse(screen, (255,255,255), (154,639,30,20))
    pygame.draw.polygon(screen, (200,113,55), [(83,563),(38,592),(18,536),(83,563)])
    pygame.draw.polygon(screen, (68,40,15), [(83,563),(38,592),(18,536),(83,563)],2)
    pygame.draw.polygon(screen, (222,170,135), [(27,545), (71,567),(44,583),(27,545)])
    pygame.draw.polygon(screen, (68,40,15), [(27,545), (71,567),(44,583),(27,545)],2)
    pygame.draw.polygon(screen, (200,113,55), [(166,563),(212,592),(216,536),(166,563)])
    pygame.draw.polygon(screen, (68,40,15), [(166,563),(212,592),(216,536),(166,563)],2)
    pygame.draw.polygon(screen, (222,170,135), [(209,545), (207,580),(176,565),(209,545)])
    pygame.draw.polygon(screen, (68,40,15), [(209,545), (207,580),(176,565),(209,545)],2)
    pygame.draw.polygon(screen, (222,170,135), [(120,686), (146,686),(133,699),(120,686)])
    pygame.draw.polygon(screen, (68,40,15),  [(120,686), (146,686),(133,699),(120,686)],2)
    pygame.draw.line(screen, (68,40,15), (133,699), (133,715), 2)
    us1 = pygame.Rect(133,707,14,16)
    pygame.draw.arc(screen, (68,40,15), us1, 3.3, 0, 1) 
    us2 = pygame.Rect(119,707,14,16)
    pygame.draw.arc(screen, (68,40,15), us2, 3.3, 0, 1) 
    pygame.draw.line(screen, (68,40,15), (156,699), (254,688), 1)
    pygame.draw.line(screen, (68,40,15), (165,708), (254,710), 1)
    pygame.draw.line(screen, (68,40,15), (162,717), (254,737), 1)
    pygame.draw.line(screen, (68,40,15), (110,699), (8,688), 1)
    pygame.draw.line(screen, (68,40,15), (101,708), (8,710), 1)
    pygame.draw.line(screen, (68,40,15), (104,717), (8,737), 1)

    #клубок ниток, который движется
    klubok_surface = pygame.Surface((794,1123), pygame.SRCALPHA)
    pygame.draw.line(klubok_surface, (146,140,114), (455,1020), (420,1070), 1)        
    pygame.draw.ellipse(klubok_surface, (153,153,153), (401,890,188,188)) 
    pygame.draw.ellipse(klubok_surface, (70,70,70), (401,890,188,188), 2) 
    klubok1_rect = pygame.Rect(430,920,130,130)
    pygame.draw.arc(klubok_surface, (70,70,70), klubok1_rect, -0.3, 1.6, 2)   
    klubok2_rect = pygame.Rect(410,930,130,130)
    pygame.draw.arc(klubok_surface, (70,70,70), klubok2_rect, 0.3, 1.5, 2)  
    klubok3_rect = pygame.Rect(400,960,130,130)
    pygame.draw.arc(klubok_surface, (70,70,70), klubok3_rect, 0.1, 1.8, 2) 
    klubok4_rect = pygame.Rect(450,980,130,130)
    pygame.draw.arc(klubok_surface, (70,70,70), klubok4_rect, 2.1, 3.2, 2) 
    klubok5_rect = pygame.Rect(435,965,130,130)
    pygame.draw.arc(klubok_surface, (70,70,70), klubok5_rect, 2.1, 3.2, 2) 
    klubok6_rect = pygame.Rect(475,990,130,130)
    pygame.draw.arc(klubok_surface, (70,70,70), klubok6_rect, 2.1, 3.2, 2) 
    klubok7_rect = pygame.Rect(340,1050,80,40)
    pygame.draw.arc(klubok_surface, (146,140,114), klubok7_rect, 3.14, 0, 1) 
    klubok8_rect = pygame.Rect(260,1050,80,40)
    pygame.draw.arc(klubok_surface, (146,140,114), klubok8_rect, 0, 3.14, 1) 
    klubok9_rect = pygame.Rect(180,1050,80,40)
    pygame.draw.arc(klubok_surface, (146,140,114), klubok9_rect, 3.4, 0, 1) 
    pygame.draw.line(klubok_surface, (146,140,114), (182,1075), (160,1070), 1)   
    
    screen.blit(klubok_surface, (mouse_x - 495, mouse_y - 984))


    pygame.display.flip()
 # для просмотра рисунок во всю длину
    pygame.image.save(screen, "cat.png")
pygame.quit()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
