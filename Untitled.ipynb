# %%
import turtle

t = turtle.Turtle()
t.speed(0)
turtle.bgcolor("LightSkyBlue")

t.penup()
t.goto(-300,300)
t.pendown()
t.width(100)
t.color("azure")
t.penup()
t.goto(-400,400)
t.pendown()
t.width(100)
t.goto(-200,400)
t.penup()
t.goto(-800,200)
t.pendown()
t.width(150)
t.goto(100,200)
t.penup()
t.goto(400,100)
t.pendown()
t.goto(800,100)


t.pensize(1)
t.penup()
t.goto(-100, -100)  
t.pendown()
t.color("DarkSlateGray")
t.begin_fill()
for i in range(2):
    t.forward(200)  
    t.left(90)
    t.forward(150)   
    t.left(90)
t.end_fill()

t.penup()
t.goto(-40, -40)
t.pendown()
t.color("Khaki")
t.begin_fill()
for i in range(4):
    t.forward(80)
    t.left(90)
t.end_fill()
t.color("DarkKhaki")
t.pensize(5)
for i in range(4):
    t.forward(80)
    t.left(90)
t.penup()
t.goto(0,-40)
t.pendown()
t.goto(0,40)
t.penup()
t.goto(-40,0)
t.pendown()
t.goto(40,0)


t.pensize(1)
t.penup()
t.goto(-100, 50) 
t.pendown()
t.color("peru")
t.begin_fill()
t.goto(0, 150)     
t.goto(100, 50)    
t.goto(-100, 50)   
t.end_fill()

t.penup()
t.goto(40, 80)   
t.pendown()
t.color("sienna")
t.begin_fill()
for i in range(2):
    t.forward(30)
    t.left(90)
    t.forward(60)
    t.left(90)
t.end_fill()


t.penup()
t.goto(55, 140)  
t.pendown()
t.color("gray")
for r in [15, 20, 25]:
    t.penup()
    t.goto(55, 140 + r * 2) 
    t.pendown()
    t.begin_fill()
    t.circle(r)
    t.end_fill()

t.penup()
t.goto(-1000,-100)
t.pendown()
t.color("SeaGreen")
t.begin_fill()
t.goto(1000,-100)
t.goto (1000,-500)
t.goto(-1000,-500)
t.goto(-1000,-100)
t.end_fill()

t.penup()
t.goto(-500,-250)
t.pendown()
t.color("DarkSlateGray")
t.begin_fill()
for i in range(2):
    t.forward(200)  
    t.left(90)
    t.forward(300)   
    t.left(90)
t.end_fill()

t.pensize(3)
t.penup()
t.goto(-440, -210)
t.pendown()
t.color("Khaki")
t.begin_fill()
for i in range(4):
    t.forward(40)
    t.left(90)
t.end_fill()
t.color("DarkKhaki")
for i in range(4):
    t.forward(40)
    t.left(90)
t.goto(-420,-210)
t.goto(-420,-170)
t.penup()
t.goto(-440,-190)
t.pendown()
t.goto(-400,-190)

t.penup()
t.goto(-440, -150)
t.pendown()
t.color("Khaki")
t.begin_fill()
for i in range(4):
    t.forward(40)
    t.left(90)
t.end_fill()
t.color("DarkKhaki")
for i in range(4):
    t.forward(40)
    t.left(90)
t.goto(-420,-150)
t.goto(-420,-110)
t.penup()
t.goto(-440,-130)
t.pendown()
t.goto(-400,-130)

t.penup()
t.goto(-440, -90)
t.pendown()
t.color("Khaki")
t.begin_fill()
for i in range(4):
    t.forward(40)
    t.left(90)
t.end_fill()
t.color("DarkKhaki")
for i in range(4):
    t.forward(40)
    t.left(90)
t.goto(-420,-90)
t.goto(-420,-50)
t.penup()
t.goto(-440,-70)
t.pendown()
t.goto(-400,-70)

t.penup()
t.goto(-440, -30)
t.pendown()
t.color("Khaki")
t.begin_fill()
for i in range(4):
    t.forward(40)
    t.left(90)
t.end_fill()
t.color("DarkKhaki")
for i in range(4):
    t.forward(40)
    t.left(90)
t.goto(-420,-30)
t.goto(-420,10)
t.penup()
t.goto(-440,-10)
t.pendown()
t.goto(-400,-10)

t.pensize(1)
t.penup()
t.goto(-500,50) 
t.pendown()
t.color("peru")
t.begin_fill()
t.goto(-400, 150)     
t.goto(-300, 50)    
t.goto(-500, 50)   
t.end_fill()

t.penup()
t.goto(-450, 80)   
t.pendown()
t.color("sienna")
t.begin_fill()
for i in range(2):
    t.forward(30)
    t.left(90)
    t.forward(60)
    t.left(90)
t.end_fill()


t.penup()
t.goto(-450, 140)  
t.pendown()
t.color("gray")
for r in [15, 20, 25]:
    t.penup()
    t.goto(-435, 140 + r * 2) 
    t.pendown()
    t.begin_fill()
    t.circle(r)
    t.end_fill()

t.penup()
t.goto(-450, 140)  
t.pendown()
t.color("gray")
for r in [15, 20, 25]:
    t.penup()
    t.goto(-435, 140 + r * 2) 
    t.pendown()
    t.begin_fill()
    t.circle(r)
    t.end_fill()

t.penup()
t.goto(-350,-500)
t.pendown()
t.color("black")
t.begin_fill()
t.goto(600,-100)
t.goto(700,-100)
t.goto(200,-500)
t.goto(-350,-500)
t.end_fill()

t.penup()
t.goto(500,500)
t.color("Gold")
for r in [100]:
    t.penup()
    t.goto(500, 25 + r * 2) 
    t.pendown()
    t.begin_fill()
    t.circle(r)
    t.end_fill()

turtle.done()
